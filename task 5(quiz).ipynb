# %%
quiz =[
    {
        "Q )":"Python Language Created By : ",
        "op)":["a) Dennis Ritchie","b) Guido van Rossum","c) James Gosling","d) Brendan Eich"],
        "ans":"b",
    },
    
    {
        "Q )":"Python Language Created in : ",
        "op)":["a) 1990","b) 2010","c) 2019","d) 1991"],
        "ans":"d",
    },
    
    {
        "Q )":"Which is immutable :" ,
        "op)":["a) Tuple","b) List ","c) dictionary","d) None Of These"],
        "ans":"a",
    },
    
    {
        "Q )":"Which is mutable :" ,
        "op)":["a) Tuple","b) List ","c) String","d) None Of These"],
        "ans":"b",
    },
    
    {
        "Q )":"What is The Output Of Following Code :\n print(2+2*2)" ,
        "op)":["a) 2","b) 8 ","c) 6","d) 4"],
        "ans":"c",
    },
    
    {
        "Q )":"What is the output of the following code? :\n str =python \n print (str[1:3])" ,
        "op)":["a) pyt","b) py","c) th","d) yt"],
        "ans":"d",
    },
    
    {
        "Q )":"What is the data type of print(type(10)? :" ,
        "op)":["a) int","b) String","c) Float","d) List"],
        "ans":"a",
    },
    
    {
        "Q )":"What is the data type of print(type(10.6)? :" ,
        "op)":["a) int","b) String","c) Float","d) List"],
        "ans":"c",
    },
    
    {
        "Q )":"Which Function To Check The Length Of List or String :" ,
        "op)":["a) length","b) len","c) int","d) str"],
        "ans":"b",
    },
    
    {
        "Q )":"What is the output of the following code :\n x = 6,y = 2, print(x // y)" ,
        "op)":["a) 0","b) 3.0","c) 12","d) 3"],
        "ans":"d",
    }
]

Name=input("Enter Your Name\n")
print("**********************************QUIZ MADE BY MUHAMMAD ZUBAIR MINHAS************************\n")
print("=============================WELCOME ",Name.upper() ,"IN PYTHON LANGUAGE QUIZ===================================\n")



i=0
mar=0
for question in quiz:
    i=i+1
    print("Q No:",i,")",question["Q )"])
    print(question["op)"][0])
    print(question["op)"][1])
    print(question["op)"][2])
    print(question["op)"][3])
    inp=input("\nEnter  Option :")
    if inp.lower() == question["ans"]:
        print("Your Answer Is Correct\n\n")
        mar +=1
    else:
        print("Your Answer Is Incorrect")
        print("Correct Anwer :",question["ans"],"\n")
print("Quiz Completed\n",Name,"Your Total Score :",mar)
# Out:
# Enter Your Name
# Asad Khan
# **********************************QUIZ MADE BY MUHAMMAD ZUBAIR MINHAS************************
#
# =============================WELCOME  ASAD KHAN IN PYTHON LANGUAGE QUIZ===================================
#
# Q No: 1 ) Python Language Created By :
# a) Dennis Ritchie
# b) Guido van Rossum
# c) James Gosling
# d) Brendan Eich
#
# Enter  Option :b
# Your Answer Is Correct
#
#
# Q No: 2 ) Python Language Created in :
# a) 1990
# b) 2010
# c) 2019
# d) 1991
#
# Enter  Option :a
# Your Answer Is Incorrect
# Correct Anwer : d
#
# Q No: 3 ) Which is immutable :
# a) Tuple
# b) List
# c) dictionary
# d) None Of These
#
# Enter  Option :a
# Your Answer Is Correct
#
#
# Q No: 4 ) Which is mutable :
# a) Tuple
# b) List
# c) String
# d) None Of These
#
# Enter  Option :b
# Your Answer Is Correct
#
#
# Q No: 5 ) What is The Output Of Following Code :
#  print(2+2*2)
# a) 2
# b) 8
# c) 6
# d) 4
#
# Enter  Option :c
# Your Answer Is Correct
#
#
# Q No: 6 ) What is the output of the following code? :
#  str =python
#  print (str[1:3])
# a) pyt
# b) py
# c) th
# d) yt
#
# Enter  Option :D
# Your Answer Is Correct
#
#
# Q No: 7 ) What is the data type of print(type(10)? :
# a) int
# b) String
# c) Float
# d) List
#
# Enter  Option :A
# Your Answer Is Correct
#
#
# Q No: 8 ) What is the data type of print(type(10.6)? :
# a) int
# b) String
# c) Float
# d) List
#
# Enter  Option :C
# Your Answer Is Correct
#
#
# Q No: 9 ) Which Function To Check The Length Of List or String :
# a) length
# b) len
# c) int
# d) str
#
# Enter  Option :d
# Your Answer Is Incorrect
# Correct Anwer : b
#
# Q No: 10 ) What is the output of the following code :
#  x = 6,y = 2, print(x // y)
# a) 0
# b) 3.0
# c) 12
# d) 3
#
# Enter  Option :b
# Your Answer Is Incorrect
# Correct Anwer : d
#
# Quiz Completed
#  Asad Khan Your Total Score : 7
